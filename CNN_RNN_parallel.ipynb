# %%
import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Bidirectional, LSTM, Dropout, Activation, GRU
from keras.layers import Conv2D, concatenate, MaxPooling2D, Flatten, Embedding, Lambda

from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend as K
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop
from keras.utils import to_categorical

from keras import regularizers


import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load training and Validation arrays

# %%
dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 
               'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7  }


reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 2: 'Folk', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International', 6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('shuffled_train.npz')
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
y_train=to_categorical(y_train)
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394, 8)

# %%
npzfile = np.load('shuffled_valid.npz')
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
y_valid=to_categorical(y_valid)
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800, 8)

# %% [markdown]
# ### Check by plotting a Spectogram

# %%
num = 5300
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Rock

# %% [markdown]
# ### Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 8
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=16 
nb_filters2=32 
nb_filters3=64
nb_filters4=64
nb_filters5=64
ksize = (3,1)
pool_size_1= (2,2) 
pool_size_2= (4,4)
pool_size_3 = (4,2)

dropout_prob = 0.20
dense_size1 = 128
lstm_count = 64
num_units = 120

BATCH_SIZE = 64
EPOCH_COUNT = 50
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1,
                      padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1,
                      padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1,
                      padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1,
                      padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_2)(conv_4)
    
    
    conv_5 = Conv2D(filters = nb_filters5, kernel_size = ksize, strides=1,
                      padding= 'valid', activation='relu', name='conv_5')(pool_4)
    pool_5 = MaxPooling2D(pool_size_2)(conv_5)

    flatten1 = Flatten()(pool_5)
    ### Recurrent Block
    
    # Pooling layer
    pool_lstm1 = MaxPooling2D(pool_size_3, name = 'pool_lstm')(layer)
    
    # Embedding layer

    squeezed = Lambda(lambda x: K.squeeze(x, axis= -1))(pool_lstm1)
#     flatten2 = K.squeeze(pool_lstm1, axis = -1)
#     dense1 = Dense(dense_size1)(flatten)
    
    # Bidirectional GRU
    lstm = Bidirectional(GRU(lstm_count))(squeezed)  #default merge mode is concat
    
    # Concat Output
    concat = concatenate([flatten1, lstm], axis=-1, name ='concat')
    
    ## Softmax Output
    output = Dense(num_classes, activation = 'softmax', name='preds')(concat)
    
    model_output = output
    model = Model(model_input, model_output)
    
#     opt = Adam(lr=0.001)
    opt = RMSprop(lr=0.0005)  # Optimizer
    model.compile(
            loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_frequency = 128
    n_frames = 640
    #reshape and expand dims for conv2d
#     x_train = x_train.reshape(-1, n_frequency, n_frames)
    x_train = np.expand_dims(x_train, axis = -1)
    
#     x_val = x_val.reshape(-1, n_frequency, n_frames)
    x_val = np.expand_dims(x_val, axis = -1)
    
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/parallel/weights.best.h5', monitor='val_acc', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(
                monitor='val_acc', factor=0.5, patience=10, min_delta=0.01,
                verbose=1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# WARNING:tensorflow:From /home/kapish/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 640, 128, 1)  0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 638, 128, 16) 64          input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 319, 64, 16)  0           conv_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 317, 64, 32)  1568        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 158, 32, 32)  0           conv_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 156, 32, 64)  6208        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 78, 16, 64)   0           conv_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 76, 16, 64)   12352       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 19, 4, 64)    0           conv_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 17, 4, 64)    12352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# pool_lstm (MaxPooling2D)        (None, 160, 64, 1)   0           input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 1, 64)     0           conv_5[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 160, 64)      0           pool_lstm[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 128)          49536       lambda_1[0][0]
# __________________________________________________________________________________________________
# concat (Concatenate)            (None, 384)          0           flatten_1[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# preds (Dense)                   (None, 8)            3080        concat[0][0]
# ==================================================================================================
# Total params: 85,160
# Trainable params: 85,160
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training...
# WARNING:tensorflow:From /home/kapish/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 6394 samples, validate on 800 samples
# Epoch 1/50
# 6394/6394 [==============================] - 123s 19ms/step - loss: 1.9166 - accuracy: 0.2606 - val_loss: 1.7973 - val_accuracy: 0.3113
# Epoch 2/50
# /home/kapish/anaconda3/lib/python3.7/site-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# /home/kapish/anaconda3/lib/python3.7/site-packages/keras/callbacks/callbacks.py:1042: RuntimeWarning: Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: val_loss,val_accuracy,loss,accuracy,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 6394/6394 [==============================] - 125s 20ms/step - loss: 1.7557 - accuracy: 0.3455 - val_loss: 1.7205 - val_accuracy: 0.3600
# Epoch 3/50
# 6394/6394 [==============================] - 126s 20ms/step - loss: 1.6843 - accuracy: 0.3764 - val_loss: 1.7926 - val_accuracy: 0.3350
# Epoch 4/50
# 6394/6394 [==============================] - 127s 20ms/step - loss: 1.6236 - accuracy: 0.4132 - val_loss: 1.6909 - val_accuracy: 0.3638
# Epoch 5/50
# 6394/6394 [==============================] - 128s 20ms/step - loss: 1.5844 - accuracy: 0.4210 - val_loss: 1.6299 - val_accuracy: 0.3812
# Epoch 6/50
# 6394/6394 [==============================] - 127s 20ms/step - loss: 1.5546 - accuracy: 0.4371 - val_loss: 1.6424 - val_accuracy: 0.3800
# Epoch 7/50
# 6394/6394 [==============================] - 130s 20ms/step - loss: 1.5235 - accuracy: 0.4506 - val_loss: 1.6685 - val_accuracy: 0.3450
# Epoch 8/50
# 6394/6394 [==============================] - 137s 21ms/step - loss: 1.5035 - accuracy: 0.4647 - val_loss: 1.5495 - val_accuracy: 0.4325
# Epoch 9/50
# 6394/6394 [==============================] - 134s 21ms/step - loss: 1.4787 - accuracy: 0.4745 - val_loss: 1.4967 - val_accuracy: 0.4613
# Epoch 10/50
# 6394/6394 [==============================] - 134s 21ms/step - loss: 1.4582 - accuracy: 0.4817 - val_loss: 1.5133 - val_accuracy: 0.4500
# Epoch 11/50
# 6394/6394 [==============================] - 135s 21ms/step - loss: 1.4307 - accuracy: 0.4883 - val_loss: 1.6436 - val_accuracy: 0.4212
# Epoch 12/50
# 6394/6394 [==============================] - 136s 21ms/step - loss: 1.4241 - accuracy: 0.4942 - val_loss: 1.5087 - val_accuracy: 0.4550
# Epoch 13/50
# 6394/6394 [==============================] - 135s 21ms/step - loss: 1.3951 - accuracy: 0.5067 - val_loss: 1.5345 - val_accuracy: 0.4387
# Epoch 14/50
# 6394/6394 [==============================] - 135s 21ms/step - loss: 1.3779 - accuracy: 0.5113 - val_loss: 1.5024 - val_accuracy: 0.4825
# Epoch 15/50
# 6394/6394 [==============================] - 138s 22ms/step - loss: 1.3566 - accuracy: 0.5141 - val_loss: 1.4834 - val_accuracy: 0.4613
# Epoch 16/50
# 6394/6394 [==============================] - 135s 21ms/step - loss: 1.3453 - accuracy: 0.5280 - val_loss: 1.5772 - val_accuracy: 0.4050
# Epoch 17/50
# 6394/6394 [==============================] - 129s 20ms/step - loss: 1.3287 - accuracy: 0.5280 - val_loss: 1.4461 - val_accuracy: 0.4938
# Epoch 18/50
# 6394/6394 [==============================] - 129s 20ms/step - loss: 1.3087 - accuracy: 0.5422 - val_loss: 1.5223 - val_accuracy: 0.4563
# Epoch 19/50
# 6394/6394 [==============================] - 160s 25ms/step - loss: 1.2866 - accuracy: 0.5418 - val_loss: 1.6161 - val_accuracy: 0.4000
# Epoch 20/50
# 6394/6394 [==============================] - 310s 49ms/step - loss: 1.2778 - accuracy: 0.5502 - val_loss: 1.5068 - val_accuracy: 0.4812
# Epoch 21/50
# 6394/6394 [==============================] - 226s 35ms/step - loss: 1.2609 - accuracy: 0.5579 - val_loss: 1.6708 - val_accuracy: 0.4425
# Epoch 22/50
# 6394/6394 [==============================] - 132s 21ms/step - loss: 1.2472 - accuracy: 0.5608 - val_loss: 1.4886 - val_accuracy: 0.4625
# Epoch 23/50
# 6394/6394 [==============================] - 134s 21ms/step - loss: 1.2195 - accuracy: 0.5701 - val_loss: 1.4957 - val_accuracy: 0.4675
# Epoch 24/50
# 6394/6394 [==============================] - 135s 21ms/step - loss: 1.2073 - accuracy: 0.5737 - val_loss: 1.5309 - val_accuracy: 0.4512
# Epoch 25/50
# 6394/6394 [==============================] - 135s 21ms/step - loss: 1.2025 - accuracy: 0.5763 - val_loss: 1.5184 - val_accuracy: 0.4638
# Epoch 26/50
# 6394/6394 [==============================] - 134s 21ms/step - loss: 1.1736 - accuracy: 0.5866 - val_loss: 1.5399 - val_accuracy: 0.4525
# Epoch 27/50
# 6394/6394 [==============================] - 135s 21ms/step - loss: 1.1626 - accuracy: 0.5943 - val_loss: 1.5160 - val_accuracy: 0.4563
# Epoch 28/50
# 6394/6394 [==============================] - 134s 21ms/step - loss: 1.1336 - accuracy: 0.6038 - val_loss: 1.4674 - val_accuracy: 0.5000
# Epoch 29/50
# 6394/6394 [==============================] - 136s 21ms/step - loss: 1.1286 - accuracy: 0.6024 - val_loss: 1.4720 - val_accuracy: 0.4737
# Epoch 30/50
# 6394/6394 [==============================] - 135s 21ms/step - loss: 1.1078 - accuracy: 0.6132 - val_loss: 1.5959 - val_accuracy: 0.4600
# Epoch 31/50
# 6394/6394 [==============================] - 133s 21ms/step - loss: 1.0902 - accuracy: 0.6182 - val_loss: 1.4475 - val_accuracy: 0.5013
# Epoch 32/50
# 6394/6394 [==============================] - 134s 21ms/step - loss: 1.0831 - accuracy: 0.6268 - val_loss: 1.4493 - val_accuracy: 0.4888
# Epoch 33/50
# 6394/6394 [==============================] - 134s 21ms/step - loss: 1.0567 - accuracy: 0.6279 - val_loss: 1.5719 - val_accuracy: 0.4613
# Epoch 34/50
# 6394/6394 [==============================] - 133s 21ms/step - loss: 1.0413 - accuracy: 0.6379 - val_loss: 1.5011 - val_accuracy: 0.5013
# Epoch 35/50
# 6394/6394 [==============================] - 132s 21ms/step - loss: 1.0310 - accuracy: 0.6353 - val_loss: 1.5078 - val_accuracy: 0.4725
# Epoch 36/50
# 6394/6394 [==============================] - 133s 21ms/step - loss: 1.0128 - accuracy: 0.6497 - val_loss: 1.4999 - val_accuracy: 0.4850
# Epoch 37/50
# 6394/6394 [==============================] - 133s 21ms/step - loss: 0.9900 - accuracy: 0.6556 - val_loss: 1.4601 - val_accuracy: 0.5025
# Epoch 38/50
# 6394/6394 [==============================] - 132s 21ms/step - loss: 0.9746 - accuracy: 0.6620 - val_loss: 1.5268 - val_accuracy: 0.5125
# Epoch 39/50
# 6394/6394 [==============================] - 132s 21ms/step - loss: 0.9567 - accuracy: 0.6661 - val_loss: 1.5269 - val_accuracy: 0.4812
# Epoch 40/50
# 6394/6394 [==============================] - 131s 21ms/step - loss: 0.9378 - accuracy: 0.6792 - val_loss: 1.7385 - val_accuracy: 0.4638
# Epoch 41/50
# 6394/6394 [==============================] - 132s 21ms/step - loss: 0.9181 - accuracy: 0.6850 - val_loss: 1.6532 - val_accuracy: 0.4525
# Epoch 42/50
# 6394/6394 [==============================] - 131s 20ms/step - loss: 0.9099 - accuracy: 0.6838 - val_loss: 1.5740 - val_accuracy: 0.4825
# Epoch 43/50
# 6394/6394 [==============================] - 133s 21ms/step - loss: 0.8860 - accuracy: 0.6941 - val_loss: 1.5639 - val_accuracy: 0.4787
# Epoch 44/50
# 6394/6394 [==============================] - 132s 21ms/step - loss: 0.8734 - accuracy: 0.6988 - val_loss: 1.8371 - val_accuracy: 0.4437
# Epoch 45/50
# 6394/6394 [==============================] - 133s 21ms/step - loss: 0.8402 - accuracy: 0.7082 - val_loss: 1.8245 - val_accuracy: 0.4275
# Epoch 46/50
# 6394/6394 [==============================] - 133s 21ms/step - loss: 0.8366 - accuracy: 0.7119 - val_loss: 1.5726 - val_accuracy: 0.5050
# Epoch 47/50
# 6394/6394 [==============================] - 134s 21ms/step - loss: 0.8013 - accuracy: 0.7246 - val_loss: 1.6214 - val_accuracy: 0.4775
# Epoch 48/50
# 6394/6394 [==============================] - 133s 21ms/step - loss: 0.8041 - accuracy: 0.7232 - val_loss: 1.7424 - val_accuracy: 0.4837
# Epoch 49/50
# 6394/6394 [==============================] - 133s 21ms/step - loss: 0.7821 - accuracy: 0.7302 - val_loss: 1.5991 - val_accuracy: 0.4925
# Epoch 50/50
# 6394/6394 [==============================] - 132s 21ms/step - loss: 0.7639 - accuracy: 0.7421 - val_loss: 1.6110 - val_accuracy: 0.4850

# %%
show_summary_stats(history)
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy', 'lr'])

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_valid, axis = 1)
X_valid = np.expand_dims(X_valid, axis = -1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.45      0.50      0.48       100
#  Experimental       0.47      0.44      0.46       100
#          Folk       0.63      0.61      0.62       100
#       Hip-Hop       0.59      0.52      0.55       100
#  Instrumental       0.46      0.58      0.52       100
# International       0.64      0.53      0.58       100
#           Pop       0.16      0.22      0.19       100
#          Rock       0.72      0.48      0.57       100
#
#      accuracy                           0.48       800
#     macro avg       0.52      0.48      0.49       800
#  weighted avg       0.52      0.48      0.49       800

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.485

# %% [markdown]
# ### Look at the Test Set

# %%
npzfile = np.load('test_arr.npz')
print(npzfile.files)
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
from keras.models import load_model

weights_path = 'models/parallel/weights.best.h5'
model = load_model(weights_path)

# %%
y_test -= 1
print(np.amin(y_test), np.amax(y_test), np.mean(y_test))
# Out:
# 0 7 3.5

# %%
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0000008783668917 0.004623813072130021

# %%
X_test = np.log(X_test_raw)


from sklearn.metrics import classification_report

y_true = y_test
X_test = np.expand_dims(X_test, axis = -1)
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.59      0.51      0.55       100
#  Experimental       0.30      0.30      0.30       100
#          Folk       0.24      0.28      0.26       100
#       Hip-Hop       0.63      0.80      0.70       100
#  Instrumental       0.43      0.41      0.42       100
# International       0.58      0.45      0.51       100
#           Pop       0.26      0.19      0.22       100
#          Rock       0.49      0.61      0.54       100
#
#      accuracy                           0.44       800
#     macro avg       0.44      0.44      0.44       800
#  weighted avg       0.44      0.44      0.44       800

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns


mat = confusion_matrix(y_true, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=dict_genres.keys(),
            yticklabels=dict_genres.keys())
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_true, y_pred))
# Out:
# 0.44375
